# %% [markdown]
# # RPS Classification에 QAT 적용

# %% [markdown]
# ## Install TensorFlow Model Optimization Toolkit
# * 설치 완료 후 반드시 Runtime 재시작!
#     * '런타임' > '세션 다시 시작' 메뉴 선택

# %%
# !pip install tensorflow-model-optimization
# Out:
# Requirement already satisfied: tensorflow-model-optimization in /usr/local/lib/python3.12/dist-packages (0.8.0)
# Requirement already satisfied: absl-py~=1.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (1.4.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (0.1.9)
# Requirement already satisfied: numpy~=1.23 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (1.26.4)
# Requirement already satisfied: six~=1.14 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (1.17.0)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.12/dist-packages (from dm-tree~=0.1.1->tensorflow-model-optimization) (25.4.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.12/dist-packages (from dm-tree~=0.1.1->tensorflow-model-optimization) (2.1.1)

# %% [markdown]
# ## 모듈 로딩

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import glob
import cv2
from sklearn.model_selection import train_test_split
import tensorflow_model_optimization as tfmot
from tensorflow_model_optimization.python.core.keras.compat import keras

print("NumPy Version :{}".format(np.__version__))
print("TensorFlow Version :{}".format(tf.__version__))
print("Matplotlib Version :{}".format(plt.matplotlib.__version__))
# Out:
# NumPy Version :1.26.4
# TensorFlow Version :2.19.0
# Matplotlib Version :3.10.0

# %% [markdown]
# ### g-drive 마운트

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive')
    print('g-drive mounted.')
    colab=True
except:
    print('local drive.')
    colab =False
# Out:
# Mounted at /content/drive
# g-drive mounted.

# %% [markdown]
# ### RPS 데이터셋 준비

# %%
# files_path: 다른 경로에 실습파일을 복사했다면, 아래 경로를 수정하세요

if colab :
  # !unzip -q -o /content/drive/MyDrive/files/RPS_Dataset.zip
  files_path = '/content/RPS_Dataset'
else :
  files_path = '../files/RPS_Dataset'

# %% [markdown]
# ### 폴더 별로 파일 읽어 데이터화 진행

# %%
IMG_SIZE = 224

# %%
# %%time
first = True
for ind in range(0, 3, 1) :
    path = files_path + '/' + str(ind) + '/*.*'
    print(path)
    files = glob.glob(path)
    tmpx = np.array([(cv2.resize(cv2.cvtColor(cv2.imread(x, cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB), (IMG_SIZE,IMG_SIZE))) for x in files])
    tmpy = np.array([ind] * len(files))

    xtrain, xtest, ytrain, ytest = train_test_split(tmpx, tmpy, test_size=0.2, random_state=123)

    if first == True:
        train_data = xtrain.copy()
        train_labels = ytrain.copy()
        test_data = xtest.copy()
        test_labels = ytest.copy()
        first = False
    else :
        train_data = np.concatenate((train_data, xtrain))
        train_labels = np.concatenate((train_labels, ytrain))
        test_data = np.concatenate((test_data, xtest))
        test_labels = np.concatenate((test_labels, ytest))
# Out:
# /content/RPS_Dataset/0/*.*
# /content/RPS_Dataset/1/*.*
# /content/RPS_Dataset/2/*.*
# CPU times: user 7.93 s, sys: 706 ms, total: 8.64 s
# Wall time: 8.77 s

# %% [markdown]
# ### 데이터 확인

# %%
# Normalization 처리 안함 (모델 내에서 -1 ~ 1로 변환 처리함)
# train_data = train_data / 255.0
# test_data = test_data / 255.0

print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (2172, 224, 224, 3)
# (2172,)
# (545, 224, 224, 3)
# (545,)

# %% [markdown]
# ### ImageDataGenerator 객체 생성

# %%
img_gen_train = keras.preprocessing.image.ImageDataGenerator(
                horizontal_flip=True,         # 좌우 반전 여부 설정
                rotation_range=0.2,          # 회전 범위 설정
                width_shift_range=0.1,       # 좌우로 이동할 범위 설정
                height_shift_range=0.1,      # 상하로 이동할 범위 설정
                brightness_range=(0.1, 0.9), # 밝기 범위 설정
                zoom_range=0.2               # 줌 범위 설정
                )                            # 이외에도 다양한 설정 가능

train_gen = img_gen_train.flow(train_data, train_labels, seed = 1)

# %% [markdown]
# ### 모델 생성

# %%
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = keras.applications.mobilenet_v2.preprocess_input(inputs)

base_model = keras.applications.MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_tensor = x
)

for layer in base_model.layers:
    if isinstance(layer, keras.layers.BatchNormalization):
        layer.trainable = False
    else:
        layer.trainable = True

x = base_model.output
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dense(128, activation='relu')(x)
x = keras.layers.Dropout(0.2)(x)
outputs = keras.layers.Dense(3, activation='softmax')(x)

model = keras.Model(inputs, outputs)

model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 2s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  tf.math.truediv (TFOpLambd  (None, 224, 224, 3)          0         ['input_1[0][0]']
#  a)
#
#  tf.math.subtract (TFOpLamb  (None, 224, 224, 3)          0         ['tf.math.truediv[0][0]']
#  da)
#
#  Conv1 (Conv2D)              (None, 112, 112, 32)         864       ['tf.math.subtract[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 112, 112, 32)         128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 112, 112, 32)         0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 112, 112, 32)         288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 112, 112, 32)         128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 112, 112, 32)         0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 112, 112, 16)         512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 112, 112, 16)         64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 112, 112, 96)         1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 112, 112, 96)         384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 112, 112, 96)         0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 113, 113, 96)         0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 56, 56, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 56, 56, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 56, 56, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 56, 56, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 56, 56, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 56, 56, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 56, 56, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 56, 56, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 56, 56, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 56, 56, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 56, 56, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 56, 56, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 56, 56, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 56, 56, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 56, 56, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 57, 57, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 28, 28, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 28, 28, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 28, 28, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 28, 28, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 28, 28, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 28, 28, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 28, 28, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 28, 28, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 28, 28, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 28, 28, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 28, 28, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 28, 28, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 29, 29, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 14, 14, 192)          1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 14, 14, 192)          768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 14, 14, 192)          0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 14, 14, 64)           12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 14, 14, 64)           0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 14, 14, 64)           0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 14, 14, 64)           0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 14, 14, 384)          24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 14, 14, 384)          1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 14, 14, 384)          0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 14, 14, 384)          3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 14, 14, 384)          1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 14, 14, 384)          0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 14, 14, 96)           36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 14, 14, 96)           384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 14, 14, 576)          5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 14, 14, 576)          0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 14, 14, 96)           55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 14, 14, 96)           384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 14, 14, 96)           0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 14, 14, 576)          5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 14, 14, 576)          0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 14, 14, 96)           55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 14, 14, 96)           384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 14, 14, 96)           0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 15, 15, 576)          0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 7, 7, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 7, 7, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 7, 7, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 7, 7, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 7, 7, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 7, 7, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 7, 7, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 7, 7, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 7, 7, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 7, 7, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 7, 7, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 7, 7, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 7, 7, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 7, 7, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 7, 7, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 7, 7, 1280)           0         ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (  (None, 1280)                 0         ['out_relu[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)                  163968    ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 3)                    387       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 2422339 (9.24 MB)
# Trainable params: 2354115 (8.98 MB)
# Non-trainable params: 68224 (266.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## 모델 컴파일

# %%
model.compile(optimizer= keras.optimizers.Adam(learning_rate=1e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 모델 학습

# %%
# %%time
history = model.fit(train_gen, epochs=30,
                    validation_data=(test_data, test_labels))
# Out:
# Epoch 1/30
# 68/68 [==============================] - 55s 504ms/step - loss: 0.6158 - accuracy: 0.7518 - val_loss: 0.2631 - val_accuracy: 0.9229
# Epoch 2/30
# 68/68 [==============================] - 33s 481ms/step - loss: 0.2356 - accuracy: 0.9231 - val_loss: 0.1271 - val_accuracy: 0.9615
# Epoch 3/30
# 68/68 [==============================] - 33s 480ms/step - loss: 0.1192 - accuracy: 0.9567 - val_loss: 0.0645 - val_accuracy: 0.9835
# Epoch 4/30
# 68/68 [==============================] - 33s 481ms/step - loss: 0.0691 - accuracy: 0.9820 - val_loss: 0.0468 - val_accuracy: 0.9890
# Epoch 5/30
# 68/68 [==============================] - 33s 485ms/step - loss: 0.0572 - accuracy: 0.9811 - val_loss: 0.0525 - val_accuracy: 0.9835
# Epoch 6/30
# 68/68 [==============================] - 32s 476ms/step - loss: 0.0375 - accuracy: 0.9913 - val_loss: 0.0254 - val_accuracy: 0.9908
# Epoch 7/30
# 68/68 [==============================] - 35s 508ms/step - loss: 0.0242 - accuracy: 0.9917 - val_loss: 0.0209 - val_accuracy: 0.9927
# Epoch 8/30
# 68/68 [==============================] - 33s 480ms/step - loss: 0.0207 - accuracy: 0.9959 - val_loss: 0.0218 - val_accuracy: 0.9927
# Epoch 9/30
# 68/68 [==============================] - 33s 481ms/step - loss: 0.0151 - accuracy: 0.9949 - val_loss: 0.0223 - val_accuracy: 0.9927
# Epoch 10/30
# 68/68 [==============================] - 34s 497ms/step - loss: 0.0193 - accuracy: 0.9936 - val_loss: 0.0207 - val_accuracy: 0.9908
# Epoch 11/30
# 68/68 [==============================] - 33s 487ms/step - loss: 0.0138 - accuracy: 0.9959 - val_loss: 0.0142 - val_accuracy: 0.9927
# Epoch 12/30
# 68/68 [==============================] - 33s 482ms/step - loss: 0.0069 - accuracy: 0.9991 - val_loss: 0.0091 - val_accuracy: 0.9963
# Epoch 13/30
# 68/68 [==============================] - 33s 489ms/step - loss: 0.0060 - accuracy: 0.9991 - val_loss: 0.0087 - val_accuracy: 0.9963
# Epoch 14/30
# 68/68 [==============================] - 33s 485ms/step - loss: 0.0073 - accuracy: 0.9982 - val_loss: 0.0107 - val_accuracy: 0.9945
# Epoch 15/30
# 68/68 [==============================] - 32s 475ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.0131 - val_accuracy: 0.9945
# Epoch 16/30
# 68/68 [==============================] - 33s 490ms/step - loss: 0.0085 - accuracy: 0.9982 - val_loss: 0.0166 - val_accuracy: 0.9963
# Epoch 17/30
# 68/68 [==============================] - 34s 493ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0074 - val_accuracy: 0.9982
# Epoch 18/30
# 68/68 [==============================] - 34s 502ms/step - loss: 0.0142 - accuracy: 0.9963 - val_loss: 0.0071 - val_accuracy: 0.9963
# Epoch 19/30
# 68/68 [==============================] - 35s 518ms/step - loss: 0.0049 - accuracy: 0.9982 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 20/30
# 68/68 [==============================] - 33s 478ms/step - loss: 0.0077 - accuracy: 0.9968 - val_loss: 0.0078 - val_accuracy: 0.9963
# Epoch 21/30
# 68/68 [==============================] - 34s 502ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 0.9982
# Epoch 22/30
# 68/68 [==============================] - 32s 474ms/step - loss: 0.0041 - accuracy: 0.9991 - val_loss: 0.0059 - val_accuracy: 0.9963
# Epoch 23/30
# 68/68 [==============================] - 33s 481ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 0.9982
# Epoch 24/30
# 68/68 [==============================] - 34s 495ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 25/30
# 68/68 [==============================] - 33s 478ms/step - loss: 0.0035 - accuracy: 0.9982 - val_loss: 0.0126 - val_accuracy: 0.9963
# Epoch 26/30
# 68/68 [==============================] - 32s 476ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 0.9982
# Epoch 27/30
# 68/68 [==============================] - 33s 485ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 28/30
# 68/68 [==============================] - 33s 485ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 0.9982
# Epoch 29/30
# 68/68 [==============================] - 33s 480ms/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 30/30
# 68/68 [==============================] - 33s 484ms/step - loss: 0.0051 - accuracy: 0.9991 - val_loss: 0.0159 - val_accuracy: 0.9963
# CPU times: user 19min 32s, sys: 9 s, total: 19min 41s
# Wall time: 17min 19s

# %% [markdown]
# ## Ploting : Cost/Training Count

# %%
plt.figure(figsize=(6, 10))
plt.subplot(2, 1, 1)
plt.title('Accuray')
plt.plot(history.history['accuracy'], 'b', label='train_accuracy')
plt.plot(history.history['val_accuracy'], 'g', label='val_accuracy')
plt.grid(True)
plt.ylabel('Accuracy')
plt.legend(loc='best')

plt.subplot(2, 1, 2)
plt.title('Loss')
plt.plot(history.history['loss'], 'b', label='train_loss')
plt.plot(history.history['val_loss'], 'g', label='val_loss')
plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## 학습 후 상황

# %%
def Make_Result_Plot(suptitle, data, label, y_max):
    size = data.shape[0]//10
    fig_result, ax_result = plt.subplots(2,5,figsize=(18, 7))
    fig_result.suptitle(suptitle)
    for idx in range(10):
        cnt = idx * size + size//2
        ax_result[idx//5,idx%5].imshow(data[cnt].reshape((IMG_SIZE,IMG_SIZE, 3)))
        ax_result[idx//5,idx%5].set_title("test_data[{}] (label : {} / y : {})".format(cnt, label[cnt], y_max[cnt]))

# %%
y_out = model.predict(test_data)
y_max = np.argmax(y_out, axis=1).reshape((-1, 1))
Make_Result_Plot("After Training", test_data, test_labels, y_max)
# Out:
# 18/18 [==============================] - 2s 41ms/step

# %% [markdown]
# ## 양자화 모델 생성

# %%
# # 선택적 양자화 함수
def apply_quantization_to_layer(layer):
    # Dense, Conv2D, DepthwiseConv2D 레이어만 양자화
    if isinstance(layer, (keras.layers.Dense, keras.layers.Conv2D, keras.layers.DepthwiseConv2D)):
        return tfmot.quantization.keras.quantize_annotate_layer(layer)

    return layer

# 모델 복제하면서 선택적 양자화 적용
annotated_model = keras.models.clone_model(
    model,
    clone_function=apply_quantization_to_layer,
)

# 양자화 적용
qat_model = tfmot.quantization.keras.quantize_apply(annotated_model)

# %%
qat_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  tf.math.truediv (TFOpLambd  (None, 224, 224, 3)          0         ['input_1[0][0]']
#  a)
#
#  tf.math.subtract (TFOpLamb  (None, 224, 224, 3)          0         ['tf.math.truediv[1][0]']
#  da)
#
#  quant_Conv1 (QuantizeWrapp  (None, 112, 112, 32)         931       ['tf.math.subtract[1][0]']
#  erV2)
#
#  bn_Conv1 (BatchNormalizati  (None, 112, 112, 32)         128       ['quant_Conv1[0][0]']
#  on)
#
#  quant_Conv1_relu (Quantize  (None, 112, 112, 32)         3         ['bn_Conv1[1][0]']
#  WrapperV2)
#
#  quant_expanded_conv_depthw  (None, 112, 112, 32)         293       ['quant_Conv1_relu[0][0]']
#  ise (QuantizeWrapperV2)
#
#  expanded_conv_depthwise_BN  (None, 112, 112, 32)         128       ['quant_expanded_conv_depthwis
#   (BatchNormalization)                                              e[0][0]']
#
#  quant_expanded_conv_depthw  (None, 112, 112, 32)         3         ['expanded_conv_depthwise_BN[1
#  ise_relu (QuantizeWrapperV                                         ][0]']
#  2)
#
#  quant_expanded_conv_projec  (None, 112, 112, 16)         547       ['quant_expanded_conv_depthwis
#  t (QuantizeWrapperV2)                                              e_relu[0][0]']
#
#  expanded_conv_project_BN (  (None, 112, 112, 16)         64        ['quant_expanded_conv_project[
#  BatchNormalization)                                                0][0]']
#
#  quant_block_1_expand (Quan  (None, 112, 112, 96)         1731      ['expanded_conv_project_BN[1][
#  tizeWrapperV2)                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 112, 112, 96)         384       ['quant_block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 112, 112, 96)         0         ['block_1_expand_BN[1][0]']
#
#  quant_block_1_pad (Quantiz  (None, 113, 113, 96)         1         ['block_1_expand_relu[1][0]']
#  eWrapperV2)
#
#  quant_block_1_depthwise (Q  (None, 56, 56, 96)           869       ['quant_block_1_pad[0][0]']
#  uantizeWrapperV2)
#
#  block_1_depthwise_BN (Batc  (None, 56, 56, 96)           384       ['quant_block_1_depthwise[0][0
#  hNormalization)                                                    ]']
#
#  quant_block_1_depthwise_re  (None, 56, 56, 96)           3         ['block_1_depthwise_BN[1][0]']
#  lu (QuantizeWrapperV2)
#
#  quant_block_1_project (Qua  (None, 56, 56, 24)           2355      ['quant_block_1_depthwise_relu
#  ntizeWrapperV2)                                                    [0][0]']
#
#  block_1_project_BN (BatchN  (None, 56, 56, 24)           96        ['quant_block_1_project[0][0]'
#  ormalization)                                                      ]
#
#  quant_block_2_expand (Quan  (None, 56, 56, 144)          3747      ['block_1_project_BN[1][0]']
#  tizeWrapperV2)
#
#  block_2_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['quant_block_2_expand[0][0]']
#  rmalization)
#
#  quant_block_2_expand_relu   (None, 56, 56, 144)          3         ['block_2_expand_BN[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_block_2_depthwise (Q  (None, 56, 56, 144)          1301      ['quant_block_2_expand_relu[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  block_2_depthwise_BN (Batc  (None, 56, 56, 144)          576       ['quant_block_2_depthwise[0][0
#  hNormalization)                                                    ]']
#
#  quant_block_2_depthwise_re  (None, 56, 56, 144)          3         ['block_2_depthwise_BN[1][0]']
#  lu (QuantizeWrapperV2)
#
#  quant_block_2_project (Qua  (None, 56, 56, 24)           3507      ['quant_block_2_depthwise_relu
#  ntizeWrapperV2)                                                    [0][0]']
#
#  block_2_project_BN (BatchN  (None, 56, 56, 24)           96        ['quant_block_2_project[0][0]'
#  ormalization)                                                      ]
#
#  quant_block_2_add (Quantiz  (None, 56, 56, 24)           3         ['block_1_project_BN[1][0]',
#  eWrapperV2)                                                         'block_2_project_BN[1][0]']
#
#  quant_block_3_expand (Quan  (None, 56, 56, 144)          3747      ['quant_block_2_add[0][0]']
#  tizeWrapperV2)
#
#  block_3_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['quant_block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 56, 56, 144)          0         ['block_3_expand_BN[1][0]']
#
#  quant_block_3_pad (Quantiz  (None, 57, 57, 144)          1         ['block_3_expand_relu[1][0]']
#  eWrapperV2)
#
#  quant_block_3_depthwise (Q  (None, 28, 28, 144)          1301      ['quant_block_3_pad[0][0]']
#  uantizeWrapperV2)
#
#  block_3_depthwise_BN (Batc  (None, 28, 28, 144)          576       ['quant_block_3_depthwise[0][0
#  hNormalization)                                                    ]']
#
#  quant_block_3_depthwise_re  (None, 28, 28, 144)          3         ['block_3_depthwise_BN[1][0]']
#  lu (QuantizeWrapperV2)
#
#  quant_block_3_project (Qua  (None, 28, 28, 32)           4675      ['quant_block_3_depthwise_relu
#  ntizeWrapperV2)                                                    [0][0]']
#
#  block_3_project_BN (BatchN  (None, 28, 28, 32)           128       ['quant_block_3_project[0][0]'
#  ormalization)                                                      ]
#
#  quant_block_4_expand (Quan  (None, 28, 28, 192)          6531      ['block_3_project_BN[1][0]']
#  tizeWrapperV2)
#
#  block_4_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['quant_block_4_expand[0][0]']
#  rmalization)
#
#  quant_block_4_expand_relu   (None, 28, 28, 192)          3         ['block_4_expand_BN[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_block_4_depthwise (Q  (None, 28, 28, 192)          1733      ['quant_block_4_expand_relu[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  block_4_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['quant_block_4_depthwise[0][0
#  hNormalization)                                                    ]']
#
#  quant_block_4_depthwise_re  (None, 28, 28, 192)          3         ['block_4_depthwise_BN[1][0]']
#  lu (QuantizeWrapperV2)
#
#  quant_block_4_project (Qua  (None, 28, 28, 32)           6211      ['quant_block_4_depthwise_relu
#  ntizeWrapperV2)                                                    [0][0]']
#
#  block_4_project_BN (BatchN  (None, 28, 28, 32)           128       ['quant_block_4_project[0][0]'
#  ormalization)                                                      ]
#
#  quant_block_4_add (Quantiz  (None, 28, 28, 32)           3         ['block_3_project_BN[1][0]',
#  eWrapperV2)                                                         'block_4_project_BN[1][0]']
#
#  quant_block_5_expand (Quan  (None, 28, 28, 192)          6531      ['quant_block_4_add[0][0]']
#  tizeWrapperV2)
#
#  block_5_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['quant_block_5_expand[0][0]']
#  rmalization)
#
#  quant_block_5_expand_relu   (None, 28, 28, 192)          3         ['block_5_expand_BN[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_block_5_depthwise (Q  (None, 28, 28, 192)          1733      ['quant_block_5_expand_relu[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  block_5_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['quant_block_5_depthwise[0][0
#  hNormalization)                                                    ]']
#
#  quant_block_5_depthwise_re  (None, 28, 28, 192)          3         ['block_5_depthwise_BN[1][0]']
#  lu (QuantizeWrapperV2)
#
#  quant_block_5_project (Qua  (None, 28, 28, 32)           6211      ['quant_block_5_depthwise_relu
#  ntizeWrapperV2)                                                    [0][0]']
#
#  block_5_project_BN (BatchN  (None, 28, 28, 32)           128       ['quant_block_5_project[0][0]'
#  ormalization)                                                      ]
#
#  quant_block_5_add (Quantiz  (None, 28, 28, 32)           3         ['quant_block_4_add[0][0]',
#  eWrapperV2)                                                         'block_5_project_BN[1][0]']
#
#  quant_block_6_expand (Quan  (None, 28, 28, 192)          6531      ['quant_block_5_add[0][0]']
#  tizeWrapperV2)
#
#  block_6_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['quant_block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_6_expand_BN[1][0]']
#
#  quant_block_6_pad (Quantiz  (None, 29, 29, 192)          1         ['block_6_expand_relu[1][0]']
#  eWrapperV2)
#
#  quant_block_6_depthwise (Q  (None, 14, 14, 192)          1733      ['quant_block_6_pad[0][0]']
#  uantizeWrapperV2)
#
#  block_6_depthwise_BN (Batc  (None, 14, 14, 192)          768       ['quant_block_6_depthwise[0][0
#  hNormalization)                                                    ]']
#
#  quant_block_6_depthwise_re  (None, 14, 14, 192)          3         ['block_6_depthwise_BN[1][0]']
#  lu (QuantizeWrapperV2)
#
#  quant_block_6_project (Qua  (None, 14, 14, 64)           12419     ['quant_block_6_depthwise_relu
#  ntizeWrapperV2)                                                    [0][0]']
#
#  block_6_project_BN (BatchN  (None, 14, 14, 64)           256       ['quant_block_6_project[0][0]'
#  ormalization)                                                      ]
#
#  quant_block_7_expand (Quan  (None, 14, 14, 384)          25347     ['block_6_project_BN[1][0]']
#  tizeWrapperV2)
#
#  block_7_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['quant_block_7_expand[0][0]']
#  rmalization)
#
#  quant_block_7_expand_relu   (None, 14, 14, 384)          3         ['block_7_expand_BN[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_block_7_depthwise (Q  (None, 14, 14, 384)          3461      ['quant_block_7_expand_relu[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  block_7_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['quant_block_7_depthwise[0][0
#  hNormalization)                                                    ]']
#
#  quant_block_7_depthwise_re  (None, 14, 14, 384)          3         ['block_7_depthwise_BN[1][0]']
#  lu (QuantizeWrapperV2)
#
#  quant_block_7_project (Qua  (None, 14, 14, 64)           24707     ['quant_block_7_depthwise_relu
#  ntizeWrapperV2)                                                    [0][0]']
#
#  block_7_project_BN (BatchN  (None, 14, 14, 64)           256       ['quant_block_7_project[0][0]'
#  ormalization)                                                      ]
#
#  quant_block_7_add (Quantiz  (None, 14, 14, 64)           3         ['block_6_project_BN[1][0]',
#  eWrapperV2)                                                         'block_7_project_BN[1][0]']
#
#  quant_block_8_expand (Quan  (None, 14, 14, 384)          25347     ['quant_block_7_add[0][0]']
#  tizeWrapperV2)
#
#  block_8_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['quant_block_8_expand[0][0]']
#  rmalization)
#
#  quant_block_8_expand_relu   (None, 14, 14, 384)          3         ['block_8_expand_BN[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_block_8_depthwise (Q  (None, 14, 14, 384)          3461      ['quant_block_8_expand_relu[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  block_8_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['quant_block_8_depthwise[0][0
#  hNormalization)                                                    ]']
#
#  quant_block_8_depthwise_re  (None, 14, 14, 384)          3         ['block_8_depthwise_BN[1][0]']
#  lu (QuantizeWrapperV2)
#
#  quant_block_8_project (Qua  (None, 14, 14, 64)           24707     ['quant_block_8_depthwise_relu
#  ntizeWrapperV2)                                                    [0][0]']
#
#  block_8_project_BN (BatchN  (None, 14, 14, 64)           256       ['quant_block_8_project[0][0]'
#  ormalization)                                                      ]
#
#  quant_block_8_add (Quantiz  (None, 14, 14, 64)           3         ['quant_block_7_add[0][0]',
#  eWrapperV2)                                                         'block_8_project_BN[1][0]']
#
#  quant_block_9_expand (Quan  (None, 14, 14, 384)          25347     ['quant_block_8_add[0][0]']
#  tizeWrapperV2)
#
#  block_9_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['quant_block_9_expand[0][0]']
#  rmalization)
#
#  quant_block_9_expand_relu   (None, 14, 14, 384)          3         ['block_9_expand_BN[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_block_9_depthwise (Q  (None, 14, 14, 384)          3461      ['quant_block_9_expand_relu[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  block_9_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['quant_block_9_depthwise[0][0
#  hNormalization)                                                    ]']
#
#  quant_block_9_depthwise_re  (None, 14, 14, 384)          3         ['block_9_depthwise_BN[1][0]']
#  lu (QuantizeWrapperV2)
#
#  quant_block_9_project (Qua  (None, 14, 14, 64)           24707     ['quant_block_9_depthwise_relu
#  ntizeWrapperV2)                                                    [0][0]']
#
#  block_9_project_BN (BatchN  (None, 14, 14, 64)           256       ['quant_block_9_project[0][0]'
#  ormalization)                                                      ]
#
#  quant_block_9_add (Quantiz  (None, 14, 14, 64)           3         ['quant_block_8_add[0][0]',
#  eWrapperV2)                                                         'block_9_project_BN[1][0]']
#
#  quant_block_10_expand (Qua  (None, 14, 14, 384)          25347     ['quant_block_9_add[0][0]']
#  ntizeWrapperV2)
#
#  block_10_expand_BN (BatchN  (None, 14, 14, 384)          1536      ['quant_block_10_expand[0][0]'
#  ormalization)                                                      ]
#
#  quant_block_10_expand_relu  (None, 14, 14, 384)          3         ['block_10_expand_BN[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block_10_depthwise (  (None, 14, 14, 384)          3461      ['quant_block_10_expand_relu[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  block_10_depthwise_BN (Bat  (None, 14, 14, 384)          1536      ['quant_block_10_depthwise[0][
#  chNormalization)                                                   0]']
#
#  quant_block_10_depthwise_r  (None, 14, 14, 384)          3         ['block_10_depthwise_BN[1][0]'
#  elu (QuantizeWrapperV2)                                            ]
#
#  quant_block_10_project (Qu  (None, 14, 14, 96)           37059     ['quant_block_10_depthwise_rel
#  antizeWrapperV2)                                                   u[0][0]']
#
#  block_10_project_BN (Batch  (None, 14, 14, 96)           384       ['quant_block_10_project[0][0]
#  Normalization)                                                     ']
#
#  quant_block_11_expand (Qua  (None, 14, 14, 576)          56451     ['block_10_project_BN[1][0]']
#  ntizeWrapperV2)
#
#  block_11_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['quant_block_11_expand[0][0]'
#  ormalization)                                                      ]
#
#  quant_block_11_expand_relu  (None, 14, 14, 576)          3         ['block_11_expand_BN[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block_11_depthwise (  (None, 14, 14, 576)          5189      ['quant_block_11_expand_relu[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  block_11_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['quant_block_11_depthwise[0][
#  chNormalization)                                                   0]']
#
#  quant_block_11_depthwise_r  (None, 14, 14, 576)          3         ['block_11_depthwise_BN[1][0]'
#  elu (QuantizeWrapperV2)                                            ]
#
#  quant_block_11_project (Qu  (None, 14, 14, 96)           55491     ['quant_block_11_depthwise_rel
#  antizeWrapperV2)                                                   u[0][0]']
#
#  block_11_project_BN (Batch  (None, 14, 14, 96)           384       ['quant_block_11_project[0][0]
#  Normalization)                                                     ']
#
#  quant_block_11_add (Quanti  (None, 14, 14, 96)           3         ['block_10_project_BN[1][0]',
#  zeWrapperV2)                                                        'block_11_project_BN[1][0]']
#
#  quant_block_12_expand (Qua  (None, 14, 14, 576)          56451     ['quant_block_11_add[0][0]']
#  ntizeWrapperV2)
#
#  block_12_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['quant_block_12_expand[0][0]'
#  ormalization)                                                      ]
#
#  quant_block_12_expand_relu  (None, 14, 14, 576)          3         ['block_12_expand_BN[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block_12_depthwise (  (None, 14, 14, 576)          5189      ['quant_block_12_expand_relu[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  block_12_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['quant_block_12_depthwise[0][
#  chNormalization)                                                   0]']
#
#  quant_block_12_depthwise_r  (None, 14, 14, 576)          3         ['block_12_depthwise_BN[1][0]'
#  elu (QuantizeWrapperV2)                                            ]
#
#  quant_block_12_project (Qu  (None, 14, 14, 96)           55491     ['quant_block_12_depthwise_rel
#  antizeWrapperV2)                                                   u[0][0]']
#
#  block_12_project_BN (Batch  (None, 14, 14, 96)           384       ['quant_block_12_project[0][0]
#  Normalization)                                                     ']
#
#  quant_block_12_add (Quanti  (None, 14, 14, 96)           3         ['quant_block_11_add[0][0]',
#  zeWrapperV2)                                                        'block_12_project_BN[1][0]']
#
#  quant_block_13_expand (Qua  (None, 14, 14, 576)          56451     ['quant_block_12_add[0][0]']
#  ntizeWrapperV2)
#
#  block_13_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['quant_block_13_expand[0][0]'
#  ormalization)                                                      ]
#
#  block_13_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_13_expand_BN[1][0]']
#  )
#
#  quant_block_13_pad (Quanti  (None, 15, 15, 576)          1         ['block_13_expand_relu[1][0]']
#  zeWrapperV2)
#
#  quant_block_13_depthwise (  (None, 7, 7, 576)            5189      ['quant_block_13_pad[0][0]']
#  QuantizeWrapperV2)
#
#  block_13_depthwise_BN (Bat  (None, 7, 7, 576)            2304      ['quant_block_13_depthwise[0][
#  chNormalization)                                                   0]']
#
#  quant_block_13_depthwise_r  (None, 7, 7, 576)            3         ['block_13_depthwise_BN[1][0]'
#  elu (QuantizeWrapperV2)                                            ]
#
#  quant_block_13_project (Qu  (None, 7, 7, 160)            92483     ['quant_block_13_depthwise_rel
#  antizeWrapperV2)                                                   u[0][0]']
#
#  block_13_project_BN (Batch  (None, 7, 7, 160)            640       ['quant_block_13_project[0][0]
#  Normalization)                                                     ']
#
#  quant_block_14_expand (Qua  (None, 7, 7, 960)            155523    ['block_13_project_BN[1][0]']
#  ntizeWrapperV2)
#
#  block_14_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['quant_block_14_expand[0][0]'
#  ormalization)                                                      ]
#
#  quant_block_14_expand_relu  (None, 7, 7, 960)            3         ['block_14_expand_BN[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block_14_depthwise (  (None, 7, 7, 960)            8645      ['quant_block_14_expand_relu[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  block_14_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['quant_block_14_depthwise[0][
#  chNormalization)                                                   0]']
#
#  quant_block_14_depthwise_r  (None, 7, 7, 960)            3         ['block_14_depthwise_BN[1][0]'
#  elu (QuantizeWrapperV2)                                            ]
#
#  quant_block_14_project (Qu  (None, 7, 7, 160)            153923    ['quant_block_14_depthwise_rel
#  antizeWrapperV2)                                                   u[0][0]']
#
#  block_14_project_BN (Batch  (None, 7, 7, 160)            640       ['quant_block_14_project[0][0]
#  Normalization)                                                     ']
#
#  quant_block_14_add (Quanti  (None, 7, 7, 160)            3         ['block_13_project_BN[1][0]',
#  zeWrapperV2)                                                        'block_14_project_BN[1][0]']
#
#  quant_block_15_expand (Qua  (None, 7, 7, 960)            155523    ['quant_block_14_add[0][0]']
#  ntizeWrapperV2)
#
#  block_15_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['quant_block_15_expand[0][0]'
#  ormalization)                                                      ]
#
#  quant_block_15_expand_relu  (None, 7, 7, 960)            3         ['block_15_expand_BN[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block_15_depthwise (  (None, 7, 7, 960)            8645      ['quant_block_15_expand_relu[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  block_15_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['quant_block_15_depthwise[0][
#  chNormalization)                                                   0]']
#
#  quant_block_15_depthwise_r  (None, 7, 7, 960)            3         ['block_15_depthwise_BN[1][0]'
#  elu (QuantizeWrapperV2)                                            ]
#
#  quant_block_15_project (Qu  (None, 7, 7, 160)            153923    ['quant_block_15_depthwise_rel
#  antizeWrapperV2)                                                   u[0][0]']
#
#  block_15_project_BN (Batch  (None, 7, 7, 160)            640       ['quant_block_15_project[0][0]
#  Normalization)                                                     ']
#
#  quant_block_15_add (Quanti  (None, 7, 7, 160)            3         ['quant_block_14_add[0][0]',
#  zeWrapperV2)                                                        'block_15_project_BN[1][0]']
#
#  quant_block_16_expand (Qua  (None, 7, 7, 960)            155523    ['quant_block_15_add[0][0]']
#  ntizeWrapperV2)
#
#  block_16_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['quant_block_16_expand[0][0]'
#  ormalization)                                                      ]
#
#  quant_block_16_expand_relu  (None, 7, 7, 960)            3         ['block_16_expand_BN[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block_16_depthwise (  (None, 7, 7, 960)            8645      ['quant_block_16_expand_relu[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  block_16_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['quant_block_16_depthwise[0][
#  chNormalization)                                                   0]']
#
#  quant_block_16_depthwise_r  (None, 7, 7, 960)            3         ['block_16_depthwise_BN[1][0]'
#  elu (QuantizeWrapperV2)                                            ]
#
#  quant_block_16_project (Qu  (None, 7, 7, 320)            307843    ['quant_block_16_depthwise_rel
#  antizeWrapperV2)                                                   u[0][0]']
#
#  block_16_project_BN (Batch  (None, 7, 7, 320)            1280      ['quant_block_16_project[0][0]
#  Normalization)                                                     ']
#
#  quant_Conv_1 (QuantizeWrap  (None, 7, 7, 1280)           412163    ['block_16_project_BN[1][0]']
#  perV2)
#
#  Conv_1_bn (BatchNormalizat  (None, 7, 7, 1280)           5120      ['quant_Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 7, 7, 1280)           0         ['Conv_1_bn[1][0]']
#
#  quant_global_average_pooli  (None, 1280)                 3         ['out_relu[1][0]']
#  ng2d (QuantizeWrapperV2)
#
#  quant_dense (QuantizeWrapp  (None, 128)                  163973    ['quant_global_average_pooling
#  erV2)                                                              2d[0][0]']
#
#  quant_dropout (QuantizeWra  (None, 128)                  1         ['quant_dense[0][0]']
#  pperV2)
#
#  quant_dense_1 (QuantizeWra  (None, 3)                    392       ['quant_dropout[0][0]']
#  pperV2)
#
# ==================================================================================================
# Total params: 2442507 (9.32 MB)
# Trainable params: 2354115 (8.98 MB)
# Non-trainable params: 88392 (345.28 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### 모델 컴파일

# %%
qat_model.compile(optimizer= keras.optimizers.Adam(learning_rate=1e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### 콜백 설정

# %%
savedModelName = 'RPS_MobileNetV2_Augmentation_QAT.h5'
callbacks = [
    keras.callbacks.ModelCheckpoint(savedModelName,
                                    save_best_only=True)
]

# %% [markdown]
# ### 모델 학습

# %%
# %%time
history = qat_model.fit(train_gen, epochs=10,
                    callbacks=callbacks,
                    validation_data=(test_data, test_labels))
# Out:
# Epoch 1/10
# 68/68 [==============================] - ETA: 0s - loss: 1.1745 - accuracy: 0.3273
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 68/68 [==============================] - 70s 695ms/step - loss: 1.1745 - accuracy: 0.3273 - val_loss: 1.0986 - val_accuracy: 0.3321
# Epoch 2/10
# 68/68 [==============================] - 45s 656ms/step - loss: 1.1081 - accuracy: 0.3297 - val_loss: 1.0986 - val_accuracy: 0.3321
# Epoch 3/10
# 68/68 [==============================] - 45s 665ms/step - loss: 1.1018 - accuracy: 0.3343 - val_loss: 1.0983 - val_accuracy: 0.3394
# Epoch 4/10
# 68/68 [==============================] - 45s 664ms/step - loss: 0.9433 - accuracy: 0.4820 - val_loss: 0.1188 - val_accuracy: 0.9523
# Epoch 5/10
# 68/68 [==============================] - 45s 648ms/step - loss: 0.1182 - accuracy: 0.9595 - val_loss: 0.0654 - val_accuracy: 0.9743
# Epoch 6/10
# 68/68 [==============================] - 44s 634ms/step - loss: 0.0495 - accuracy: 0.9839 - val_loss: 0.0131 - val_accuracy: 0.9963
# Epoch 7/10
# 68/68 [==============================] - 43s 629ms/step - loss: 0.0330 - accuracy: 0.9885 - val_loss: 0.0067 - val_accuracy: 0.9963
# Epoch 8/10
# 68/68 [==============================] - 43s 630ms/step - loss: 0.0105 - accuracy: 0.9977 - val_loss: 0.0075 - val_accuracy: 0.9963
# Epoch 9/10
# 68/68 [==============================] - 43s 627ms/step - loss: 0.0253 - accuracy: 0.9917 - val_loss: 0.0105 - val_accuracy: 0.9963
# Epoch 10/10
# 68/68 [==============================] - 55s 811ms/step - loss: 0.0080 - accuracy: 0.9972 - val_loss: 0.0060 - val_accuracy: 0.9982
# CPU times: user 10min 40s, sys: 19.9 s, total: 10min 59s
# Wall time: 9min 4s

# %% [markdown]
# > ### Ploting : Cost/Training Count

# %%
plt.figure(figsize=(6, 10))
plt.subplot(2, 1, 1)
plt.title('Accuray')
plt.plot(history.history['accuracy'], 'b', label='train_accuracy')
plt.plot(history.history['val_accuracy'], 'g', label='val_accuracy')
# plt.ylim([0,1])
plt.grid(True)
plt.ylabel('Accuracy')
plt.legend(loc='best')

plt.subplot(2, 1, 2)
plt.title('Loss')
plt.plot(history.history['loss'], 'b', label='train_loss')
plt.plot(history.history['val_loss'], 'g', label='val_loss')
# plt.ylim([0,5])
plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### best 모델 로딩 및 테스트

# %%
# 사용자 정의 객체(QuantizeWrapperV2 등)를 인식하려면 quantize_scope 필요
from tensorflow_model_optimization.quantization.keras import quantize_scope

try:
    # quantize_scope() 내에서 모델을 로드하여 사용자 정의 객체(QuantizeWrapperV2 등)를 인식시킴
    with quantize_scope():
        model_best = keras.models.load_model(savedModelName)
except ValueError as e:
    print(f"Model load failed: {e}")

# %%
y_out = model_best.predict(test_data)
y_max = np.argmax(y_out, axis=1).reshape((-1, 1))
Make_Result_Plot("After Training", test_data, test_labels, y_max)
# Out:
# 18/18 [==============================] - 4s 111ms/step

# %% [markdown]
# ### best 모델 백업

# %%
# save_dir: 다른 경로에 저장하려면, 아래 경로를 수정하세요
if colab :
  save_dir = '/content/drive/MyDrive/files/save/'
else :
  save_dir = '../files/save/'

# %%
# copy saved mode
cpCmd = f'cp {savedModelName} {save_dir}'
print(cpCmd)
# !{cpCmd}
# Out:
# cp RPS_MobileNetV2_Augmentation_QAT.h5 /content/drive/MyDrive/files/save/

# %% [markdown]
# ### LiteRT 모델로 변환

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model_best)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

# def representative_data_gen():
#   ds = tf.data.Dataset.from_tensor_slices(train_data.astype(np.float32))
#   ds = ds.shuffle(buffer_size=len(train_data))
#   for input_value in ds.batch(1).take(100):
#     yield [input_value]

# converter = tf.lite.TFLiteConverter.from_keras_model(model_best)
# converter.optimizations = [tf.lite.Optimize.DEFAULT]
# converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
# converter.inference_input_type = tf.int8
# converter.inference_output_type = tf.int8
# converter.representative_dataset = representative_data_gen

# tflite_model = converter.convert()
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(

# %% [markdown]
# ### LiteRT 모델을 파일로 저장

# %%
tfliteFileName = 'RPS_MobileNetV2_Augmentation_QAT.tflite'

# %%
open(save_dir + tfliteFileName, 'wb').write(tflite_model)
# Out:
# 4880152
